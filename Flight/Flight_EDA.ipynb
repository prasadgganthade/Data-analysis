# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
print('Imported libraries sucessfully')
# Out:
# Imported libraries sucessfully

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the adata
flight= pd.read_csv('flights_data.csv')
flight[:3]
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
# checking last fives rows
flight.tail()
# Out:
#          index  airline  flight source_city departure_time stops arrival_time  \
# 300148  300148  Vistara  UK-822     Chennai        Morning   one      Evening
# 300149  300149  Vistara  UK-826     Chennai      Afternoon   one        Night
# 300150  300150  Vistara  UK-832     Chennai  Early_Morning   one        Night
# 300151  300151  Vistara  UK-828     Chennai  Early_Morning   one      Evening
# 300152  300152  Vistara  UK-822     Chennai        Morning   one      Evening
#
#        destination_city     class  duration  days_left  price
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585

# %%
# checking description
flight.describe()
# Out:
#                index       duration      days_left          price
# count  300153.000000  300153.000000  300153.000000  300153.000000
# mean   150076.000000      12.221021      26.004751   20889.660523
# std     86646.852011       7.191997      13.561004   22697.767366
# min         0.000000       0.830000       1.000000    1105.000000
# 25%     75038.000000       6.830000      15.000000    4783.000000
# 50%    150076.000000      11.250000      26.000000    7425.000000
# 75%    225114.000000      16.170000      38.000000   42521.000000
# max    300152.000000      49.830000      49.000000  123071.000000

# %%
flight.shape
# Out:
# (300153, 12)

# %% [markdown]
# ### Data analysis

# %%
# now first remove index column from data
flight.drop(columns='index',axis=1,inplace=True)

# %%
flight.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
# Checking shape
flight.shape
# Out:
# (300153, 11)

# %%
# Find the unique air line companies
flight.airline.unique()
# Out:
# array(['SpiceJet', 'AirAsia', 'Vistara', 'GO_FIRST', 'Indigo',
#        'Air_India'], dtype=object)

# %%
flight.airline.value_counts()
# Out:
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: airline, dtype: int64

# %%
sns.countplot(data=flight,x='airline',palette='rocket')
plt.title('Air line companies and their count')
plt.show()

# %% [markdown]
# In the above Vistara has maximum count and spice jet has low count

# %% [markdown]
# ##### Source city

# %%
flight.source_city.unique()
# Out:
# array(['Delhi', 'Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %%
flight.source_city.value_counts()
# Out:
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: source_city, dtype: int64

# %%
sns.countplot(data=flight,x='source_city',palette='rocket')
plt.title('Source city vise frequency')
plt.show()

# %% [markdown]
# In the above graph Delhi and mumbai has highest frequencies and Chennai has least frequencies

# %% [markdown]
# #### Depature time

# %%
flight.departure_time.unique()
# Out:
# array(['Evening', 'Early_Morning', 'Morning', 'Afternoon', 'Night',
#        'Late_Night'], dtype=object)

# %%
flight.departure_time.value_counts()
# Out:
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: departure_time, dtype: int64

# %%
flight.departure_time.value_counts().plot(kind='bar',color=['red','pink','orange','yellow','green','black'])
plt.title('Flight departure time wise frequencies')
plt.xlabel('Departure time')
plt.ylabel('Frequencies')
plt.show()

# %% [markdown]
# In The above plot morning highest number of flights and late_night has very less flights.

# %% [markdown]
# #### Stops

# %%
sns.countplot(data=flight,x='stops',palette='viridis')
plt.title('Number of stops taken by airline in the frequencies')
plt.show()

# %% [markdown]
# In the above plot one stops choosen flights are more in number and two or more stops provided by airlines has very less counts.

# %%
# arrival time
sns.countplot(data=flight,x='arrival_time',palette='Reds')
plt.title('Arrival time frequency')
plt.show()

# %% [markdown]
# In the above plot highest frequencies are in the night and late_night has vey less frequency.

# %%
#destination city
sns.countplot(data=flight,x='destination_city',palette='Blues')
plt.title('Destination city')
plt.show()

# %% [markdown]
# In the above plot mumbai has highest frequency and Chennai has less frequency.

# %%
#class
sns.countplot(data=flight,x='class',palette='Greens')
plt.title('Class wise frequency')
plt.show()

# %% [markdown]
# Economy class has highest frequency.

# %%
sns.countplot(data=flight,x='airline',hue='class')
# Out:
# <AxesSubplot:xlabel='airline', ylabel='count'>

# %%
flight.plot(kind='scatter',x='duration',y='price')
# Out:
# <AxesSubplot:xlabel='duration', ylabel='price'>

# %%
flight.plot(kind='scatter',x='days_left',y='price')
# Out:
# <AxesSubplot:xlabel='days_left', ylabel='price'>

# %%
sns.relplot(col="departure_time", y="price", kind="line",x='arrival_time', data=flight)

# %%
# Now check 
flight.groupby('source_city').get_group('Mumbai')
# Out:
#          airline   flight source_city departure_time        stops  \
# 43027    Vistara   UK-994      Mumbai        Morning         zero
# 43028    Vistara   UK-910      Mumbai        Evening         zero
# 43029   GO_FIRST   G8-339      Mumbai        Evening         zero
# 43030     Indigo  6E-6004      Mumbai        Evening         zero
# 43031     Indigo  6E-2077      Mumbai      Afternoon         zero
# ...          ...      ...         ...            ...          ...
# 244835   Vistara   UK-996      Mumbai        Evening          one
# 244836   Vistara   UK-940      Mumbai        Evening          one
# 244837   Vistara   UK-996      Mumbai        Evening          one
# 244838   Vistara   UK-613      Mumbai      Afternoon  two_or_more
# 244839   Vistara   UK-877      Mumbai        Morning  two_or_more
#
#        arrival_time destination_city     class  duration  days_left  price
# 43027     Afternoon            Delhi   Economy      2.25          1   5943
# ...

# %%
# Finding airline-vistara and source_coty- mumbai flights
mum_vis = flight.groupby(['airline','source_city']).get_group(('Vistara','Mumbai'))
mum_vis
# Out:
#         airline  flight source_city departure_time        stops arrival_time  \
# 43027   Vistara  UK-994      Mumbai        Morning         zero    Afternoon
# 43028   Vistara  UK-910      Mumbai        Evening         zero      Evening
# 43037   Vistara  UK-958      Mumbai      Afternoon         zero    Afternoon
# 43038   Vistara  UK-960      Mumbai        Morning         zero    Afternoon
# 43043   Vistara  UK-940      Mumbai        Evening         zero        Night
# ...         ...     ...         ...            ...          ...          ...
# 244835  Vistara  UK-996      Mumbai        Evening          one      Morning
# 244836  Vistara  UK-940      Mumbai        Evening          one        Night
# 244837  Vistara  UK-996      Mumbai        Evening          one        Night
# 244838  Vistara  UK-613      Mumbai      Afternoon  two_or_more        Night
# 244839  Vistara  UK-877      Mumbai        Morning  two_or_more        Night
#
# ...

# %%
mum_vis.query('destination_city == "Delhi" & departure_time == "Evening"')
# Out:
#         airline  flight source_city departure_time stops arrival_time  \
# 43028   Vistara  UK-910      Mumbai        Evening  zero      Evening
# 43043   Vistara  UK-940      Mumbai        Evening  zero        Night
# 43049   Vistara  UK-996      Mumbai        Evening  zero        Night
# 43062   Vistara  UK-651      Mumbai        Evening   one      Evening
# 43075   Vistara  UK-875      Mumbai        Evening   one    Afternoon
# ...         ...     ...         ...            ...   ...          ...
# 229942  Vistara  UK-875      Mumbai        Evening   one    Afternoon
# 229944  Vistara  UK-875      Mumbai        Evening   one      Evening
# 229958  Vistara  UK-823      Mumbai        Evening   one        Night
# 229963  Vistara  UK-823      Mumbai        Evening   one      Morning
# 229968  Vistara  UK-849      Mumbai        Evening   one        Night
#
#        destination_city     class  duration  days_left  price
# 43028             Delhi   Economy      2.17          1   6048
# ...

# %%
mum_vis[(mum_vis.destination_city == "Delhi") & (mum_vis.departure_time == "Afternoon")]
# Out:
#         airline  flight source_city departure_time stops arrival_time  \
# 43037   Vistara  UK-958      Mumbai      Afternoon  zero    Afternoon
# 43044   Vistara  UK-944      Mumbai      Afternoon  zero      Evening
# 43074   Vistara  UK-613      Mumbai      Afternoon   one      Evening
# 43081   Vistara  UK-852      Mumbai      Afternoon   one      Evening
# 43088   Vistara  UK-853      Mumbai      Afternoon   one        Night
# ...         ...     ...         ...            ...   ...          ...
# 229966  Vistara  UK-853      Mumbai      Afternoon   one        Night
# 229969  Vistara  UK-853      Mumbai      Afternoon   one        Night
# 229972  Vistara  UK-853      Mumbai      Afternoon   one        Night
# 229982  Vistara  UK-775      Mumbai      Afternoon   one        Night
# 229983  Vistara  UK-775      Mumbai      Afternoon   one        Night
#
#        destination_city     class  duration  days_left  price
# 43037             Delhi   Economy      2.08          1   6363
# ...

# %%
# Now check source_city flights counts
flight.groupby('airline')['source_city'].value_counts()
# Out:
# airline    source_city
# AirAsia    Delhi           4387
#            Bangalore       3364
#            Kolkata         2829
#            Mumbai          2176
#            Hyderabad       1844
#            Chennai         1498
# Air_India  Mumbai         18377
#            Delhi          17063
#            Kolkata        12400
#            Bangalore      12052
#            Hyderabad      11088
#            Chennai         9912
# GO_FIRST   Delhi           5724
#            Mumbai          5568
#            Bangalore       4498
#            Kolkata         3590
#            Hyderabad       2504
#            Chennai         1289
# Indigo     Delhi           8277
#            Mumbai          7506
#            Kolkata         7296
#            Bangalore       7080
#            Chennai         6746
#            Hyderabad       6215
# SpiceJet   Delhi           2524
#            Kolkata         1947
#            Mumbai          1734
#            Bangalore       1255
# ...

# %%
mum_del = flight.query('source_city =="Mumbai" & destination_city == "Delhi"')
mum_del
# Out:
#           airline   flight source_city departure_time stops arrival_time  \
# 43027     Vistara   UK-994      Mumbai        Morning  zero    Afternoon
# 43028     Vistara   UK-910      Mumbai        Evening  zero      Evening
# 43029    GO_FIRST   G8-339      Mumbai        Evening  zero        Night
# 43030      Indigo  6E-6004      Mumbai        Evening  zero        Night
# 43031      Indigo  6E-2077      Mumbai      Afternoon  zero    Afternoon
# ...           ...      ...         ...            ...   ...          ...
# 229985    Vistara   UK-771      Mumbai  Early_Morning   one        Night
# 229986  Air_India   AI-673      Mumbai  Early_Morning   one      Evening
# 229987  Air_India   AI-774      Mumbai          Night   one      Morning
# 229988  Air_India   AI-774      Mumbai          Night   one    Afternoon
# 229989  Air_India   AI-774      Mumbai          Night   one      Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
sns.countplot(data=mum_del,x='airline',hue='class',palette='viridis')
plt.title('Frequencies of airline between mumbai to belhi hued by class')
plt.show()

# %% [markdown]
# 1. Passengers travelling from mumbai to delhi uses the business class of vistara and airindia airlines
# 2. Vistara and airindia are prefered air lines to travel
# 3. In vistara airlines both the class has almost equal counts
# 4. In go_first, indigo,spiceget,airasia in airlines passenger does not book business class

# %%
mum_del.groupby('airline')['stops'].value_counts()
# Out:
# airline    stops
# AirAsia    one             657
#            zero             88
# Air_India  one            4023
#            zero            627
# GO_FIRST   one            1087
#            zero            532
#            two_or_more      65
# Indigo     one             768
#            zero            697
# SpiceJet   zero            241
#            one             212
# Vistara    one            4412
#            zero           1400
# Name: stops, dtype: int64

# %%
sns.countplot(data=mum_del,x='airline',hue='stops',palette='rocket')
plt.title('Stops wise mumbai to delhi flight frequency')
plt.show()

# %% [markdown]
# Only go_first give 2 or more stop facility.

# %%
# Now checking price relation of economy class among the airlines
mum_del.columns
# Out:
# Index(['airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price'],
#       dtype='object')

# %%
mum_del.plot(x='price',y='days_left',kind='scatter')
# Out:
# <AxesSubplot:xlabel='price', ylabel='days_left'>

# %%
mum_del.groupby('airline')['price']

# %%
list(mum_del.groupby('airline')['price'])
# Out:
# [('AirAsia',
#   43041     6304
#   43048     8452
#   43067    13685
#   43144     6337
#   43151     7251
#            ...
#   52661     2336
#   52662     2336
#   52663     2336
#   52664     2336
#   52703     2747
#   Name: price, Length: 745, dtype: int64),
#  ('Air_India',
#   43032      5943
#   43033      5943
#   43034      5943
#   43036      5943
#   43047      8296
#             ...
#   229981    53152
#   229986    59021
#   229987    59021
#   229988    59021
#   229989    59021
#   Name: price, Length: 4650, dtype: int64),
#  ('GO_FIRST',
#   43029     5942
#   43035     5942
#   43054    12033
#   43061    12611
#   43068    14239
#            ...
#   52822     7471
#   52823     7718
#   52824     9092
#   52825     9092
#   52826     9092
#   Name: price, Length: 1684, dtype: int64),
#  ('Indigo',
#   43030    5943
#   43031    5943
#   43042    6363
#   43045    7903
#   43046    8043
#            ...
#   52710    3108
#   52711    3108
#   52712    3108
# ...

# %%
m_d_max_fare = mum_del.groupby('airline')['price'].max()

# %%
m = pd.DataFrame(data=m_d_max_fare)
m
# Out:
#             price
# airline
# AirAsia     31799
# Air_India   79954
# GO_FIRST    31773
# Indigo      21063
# SpiceJet    18909
# Vistara    111437

# %%
sns.lineplot(data=m,x='airline',y='price')
# Out:
# <AxesSubplot:xlabel='airline', ylabel='price'>

# %% [markdown]
# Vistara business class has highest price

# %%
m2 = pd.DataFrame(data=mum_del.groupby('airline')['price'].min())
m2
# Out:
#            price
# airline
# AirAsia     2336
# Air_India   2464
# GO_FIRST    2339
# Indigo      2339
# SpiceJet    2339
# Vistara     2339

# %%
sns.lineplot(data=m2,x='airline',y='price')
# Out:
# <AxesSubplot:xlabel='airline', ylabel='price'>

# %% [markdown]
# Only air india has some more pice in minimum price band

# %%
m3 = pd.DataFrame(data=mum_del.groupby('airline')['duration'].min())
m3
# Out:
#            duration
# airline
# AirAsia        2.08
# Air_India      2.00
# GO_FIRST       2.00
# Indigo         1.83
# SpiceJet       2.00
# Vistara        2.08

# %%
sns.lineplot(data=m3,x='airline',y='duration')
plt.title('Minimum Time duration between mumbai to delhi between airlines')
plt.show()

# %% [markdown]
# The indigo flights less time to travel and airasia,vistara take more time.

# %%
m4 = pd.DataFrame(data=mum_del.groupby('airline')['duration'].max())

# %%
m4
# Out:
#            duration
# airline
# AirAsia       14.58
# Air_India     28.92
# GO_FIRST      15.50
# Indigo        11.00
# SpiceJet      25.92
# Vistara       27.83

# %%
sns.lineplot(data=m4,x='airline',y='duration')
plt.title('Maximum time duration to travel from mumbai to delhi between airlines')
plt.show()

# %% [markdown]
# In the above chart airindia takes more time while indigo less time.
